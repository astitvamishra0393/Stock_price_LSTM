# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_error
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Downloading APPLE stock details from 2020 to present

# %%
ticker='AAPL'
df=yf.download(ticker,'2020-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.333885   72.394093   71.091191   71.344062  135480400
# 2020-01-03   71.630653   72.389273   71.406681   71.563221  146322800
# 2020-01-06   72.201401   72.239935   70.503539   70.754006  118387200
# 2020-01-07   71.861847   72.466330   71.642689   72.211049  108872000
# 2020-01-08   73.017822   73.318862   71.565606   71.565606  132079200
# ...                ...         ...         ...         ...        ...
# 2026-07-27  336.910004  339.570007  334.019989  334.540009   49604300
# 2026-07-28  340.079987  342.890015  335.600006  340.029999   51859000
# 2026-07-29  338.190002  344.570007  337.350006  339.730011   56090800
# 2026-07-30  333.429993  334.750000  329.589996  333.100006   74817800
# 2026-07-31  308.910004  310.690002  300.000000  304.809998  132275300
#
# [1653 rows x 5 columns]

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform((df['Close']))

# %% [markdown]
# ### Sequence length: For every 29 days in train we need to predict the stock price of the 30th day

# %%
seq_len=30
data=[]
for i in range(len(df)-seq_len):
    data.append(scaled_data[i:i+seq_len])

data=np.array(data)
data
# Out:
# array([[[-1.76353117],
#         [-1.77563449],
#         [-1.76581136],
#         ...,
#         [-1.68055569],
#         [-1.64902042],
#         [-1.65870147]],
#
#        [[-1.77563449],
#         [-1.76581136],
#         [-1.77165542],
#         ...,
#         [-1.64902042],
#         [-1.65870147],
#         [-1.65836899]],
#
#        [[-1.76581136],
#         [-1.77165542],
#         [-1.75175994],
#         ...,
#         [-1.65870147],
#         [-1.65836899],
#         [-1.68309009]],
#
#        ...,
#
#        [[ 2.09321305],
#         [ 2.14174765],
#         [ 2.08512387],
#         ...,
#         [ 2.72313489],
#         [ 2.79008589],
#         [ 2.84464444]],
#
#        [[ 2.14174765],
#         [ 2.08512387],
#         [ 2.12057846],
#         ...,
#         [ 2.79008589],
#         [ 2.84464444],
#         [ 2.81211594]],
#
#        [[ 2.08512387],
#         [ 2.12057846],
#         [ 2.10336747],
#         ...,
#         [ 2.84464444],
#         [ 2.81211594],
#         [ 2.73019145]]], shape=(1623, 30, 1))

# %% [markdown]
# ### Converting training and Testing Data to Tensor and on cuda

# %%
train_size=int(0.8*len(data))
X_train=torch.from_numpy(data[:train_size,:-1,:]).type(torch.Tensor).to(device)
y_train=torch.from_numpy(data[:train_size,-1,:]).type(torch.Tensor).to(device)
X_test=torch.from_numpy(data[train_size:,:-1,:]).type(torch.Tensor).to(device)
y_test=torch.from_numpy(data[train_size:,-1,:]).type(torch.Tensor).to(device)

# %%
y_train
# Out:
# tensor([[-1.6587],
#         [-1.6584],
#         [-1.6831],
#         ...,
#         [ 0.3959],
#         [ 0.2516],
#         [ 0.3840]], device='cuda:0')

# %% [markdown]
# # Model Definition

# %% [markdown]
# This model can be used as a model for optuna tuned also

# %%
class PredictionModel(nn.Module):
    def __init__(
        self,
        input_size,
        hidden_size,
        num_layers,
        output_size,
        ##dropout
    ):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
           ##dropout=dropout if num_layers > 1 else 0

        )

        self.fc = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.ReLU(),
           ## nn.Dropout(dropout),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.ReLU(),
           ## nn.Dropout(dropout),
            nn.Linear(hidden_size // 4, output_size)
        )

    def forward(self, x):
        out, _ = self.lstm(x)

        # Last timestep output
        out = out[:, -1, :]

        out = self.fc(out)

        return out

# %% [markdown]
# ## Dagshub: To Track parameters using MLflow

# %%
import dagshub

dagshub.init(
    repo_owner="astitvamishra0393",
    repo_name="Stock_price_LSTM",
    mlflow=True
)

import os
os.environ["MLFLOW_TRACKING_USERNAME"] = "astitvamishra0393"

os.environ["MLFLOW_TRACKING_PASSWORD"] = "3bd956ae7246a89b696cac2a748b5de5b16083a1"
# Out:
# Accessing as astitvamishra0393
# Initialized MLflow to track repo "astitvamishra0393/Stock_price_LSTM"
# Repository astitvamishra0393/Stock_price_LSTM initialized!

# %% [markdown]
# ## Base Model

# %%
# Baseline hyperparameters

input_size = X_train.shape[2]
input_size=1
hidden_size = 32
num_layers = 2
output_size = 1

learning_rate = 0.001
epochs = 200
optimizer_name = "Adam"

# %%
model=PredictionModel(input_size=input_size,hidden_size=hidden_size,num_layers=num_layers,output_size=output_size).to(device)

# %% [markdown]
# ## Setting MLFlow url to connect it via dagshub

# %%
import mlflow
mlflow.set_tracking_uri("https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow")

mlflow.set_experiment(
    "Stock_Prediction_LSTM"
)
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/a7959eba3aa34362b10d8ba66fbd544f', creation_time=1785525045317, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1785525045317, lifecycle_stage='active', name='Stock_Prediction_LSTM', tags={}, trace_location=None, workspace='default'>

# %%
import torch.optim as optim
criterion=nn.MSELoss()
optimizer=optim.Adam(model.parameters(),lr=0.01)
from sklearn.metrics import root_mean_squared_error,mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 import torch.optim as optim
#       2 criterion=nn.MSELoss()
# ----> 3 optimizer=optim.Adam(model.parameters(),lr=0.01)
#       4 from sklearn.metrics import root_mean_squared_error,mean_squared_error
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### Running the baseline model
#
# #### In this step we follow the following steps:
# ###### 1)start mlflow run
# ###### 2)log_parameters:MLflow
# ###### 3)Training Loop
# ###### 4)Log Train Loss:MLflow
# ###### 5)Testing Loop
# ###### 6)Log Test loss:MLflow
# ###### 7)Inverse scaling: To get the final prediction not in standard format but close to value
# ###### 8)RMSE: Train and Test RMSE
# ###### 9)Plotting figures for EDA
# ###### 10)Logging figure as an artifact in MLflow
# ###### 11)Logging Model

# %%
with mlflow.start_run(run_name="Baseline_LSTM"):

    # =========================
    # Log Parameters
    # =========================

    mlflow.log_params({
        "model": "LSTM",
        "hidden_size": hidden_size,
        "num_layers": num_layers,
        "learning_rate": learning_rate,
        "epochs": epochs,
        "optimizer": "Adam",
        "loss_function": "MSELoss"
    })

    # =========================
    # Training
    # =========================

    for epoch in range(epochs):

        model.train()

        optimizer.zero_grad()

        y_train_pred = model(X_train)

        loss = criterion(
            y_train_pred,
            y_train
        )

        loss.backward()

        optimizer.step()

        if epoch % 20 == 0:
            print(
                f"Epoch [{epoch}/{epochs}] "
                f"Loss: {loss.item():.6f}"
            )

    # Final training loss

    mlflow.log_metric(
        "train_loss",
        loss.item()
    )

    # =========================
    # Testing
    # =========================

    model.eval()

    with torch.no_grad():

        y_test_pred = model(X_test)

        test_loss = criterion(
            y_test_pred,
            y_test
        )

    print(
        f"Test Loss: {test_loss.item():.6f}"
    )

    mlflow.log_metric(
        "test_loss",
        test_loss.item()
    )

    # =========================
    # Inverse Scaling
    # =========================

    y_train_pred_np = scaler.inverse_transform(
        y_train_pred.detach().cpu().numpy()
    )

    y_test_pred_np = scaler.inverse_transform(
        y_test_pred.detach().cpu().numpy()
    )

    y_train_actual = scaler.inverse_transform(
        y_train.detach().cpu().numpy()
    )

    y_test_actual = scaler.inverse_transform(
        y_test.detach().cpu().numpy()
    )

    # =========================
    # RMSE
    # =========================

    train_rmse = root_mean_squared_error(
        y_train_actual[:, 0],
        y_train_pred_np[:, 0]
    )

    test_rmse = root_mean_squared_error(
        y_test_actual[:, 0],
        y_test_pred_np[:, 0]
    )

    print(f"Train RMSE: {train_rmse:.4f}")
    print(f"Test RMSE: {test_rmse:.4f}")

    mlflow.log_metric(
        "train_rmse",
        train_rmse
    )

    mlflow.log_metric(
        "test_rmse",
        test_rmse
    )

    # =========================
    # Prediction Plot
    # =========================

    figure = plt.figure(figsize=(12, 6))

    gs = figure.add_gridspec(4, 1)

    # Price Plot
    ax1 = figure.add_subplot(gs[:3, 0])

    ax1.plot(
        df.iloc[-len(y_test_actual):].index,
        y_test_actual,
        color="blue",
        label="Actual Price"
    )

    ax1.plot(
        df.iloc[-len(y_test_actual):].index,
        y_test_pred_np,
        color="green",
        label="Predicted Price"
    )

    ax1.set_title(
        f"{ticker} Stock Price Prediction"
    )

    ax1.set_xlabel("Date")
    ax1.set_ylabel("Price")
    ax1.legend()

    # Error Plot
    ax2 = figure.add_subplot(gs[3, 0])

    ax2.axhline(
        test_rmse,
        color="blue",
        linestyle="--",
        label="RMSE"
    )

    ax2.plot(
        df.iloc[-len(y_test_actual):].index,
        abs(
            y_test_actual.flatten()
            - y_test_pred_np.flatten()
        ),
        color="red",
        label="Prediction Error"
    )

    ax2.set_title("Prediction Error")
    ax2.set_xlabel("Date")
    ax2.set_ylabel("Error")
    ax2.legend()

    plt.tight_layout()

    # =========================
    # Log Figure
    # =========================

    mlflow.log_figure(
        figure,
        "baseline_prediction.png"
    )

    # =========================
    # Save Model
    # =========================

    mlflow.pytorch.log_model(
        model,
        "baseline_model",
        serialization_format="pickle"
    )

    plt.show()
# Out:
# Epoch [0/200] Loss: 0.002612
# Epoch [20/200] Loss: 0.002591
# Epoch [40/200] Loss: 0.002572
# Epoch [60/200] Loss: 0.002556
# Epoch [80/200] Loss: 0.002543
# Epoch [100/200] Loss: 0.002534
# Epoch [120/200] Loss: 0.002527
# Epoch [140/200] Loss: 0.002523
# Epoch [160/200] Loss: 0.002519
# Epoch [180/200] Loss: 0.002515
# Test Loss: 0.018416
# Train RMSE: 2.9119
# Test RMSE: 7.8840
# 2026/08/01 02:25:14 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/08/01 02:25:18 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# 2026/08/01 02:25:18 WARNING mlflow.utils.requirements_utils: Found torch version (2.11.0+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.11.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/08/01 02:25:22 WARNING mlflow.utils.requirements_utils: Found torch version (2.11.0+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.11.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 🏃 View run Baseline_LSTM at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/0/runs/816cc3f7a84c403787604e80ae5f8679
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/0

# %%
# import mlflow

# run_ids = [
#     "6143ff53893a460a9beb511e7b8fab49",
#     "166ef4189538403c8a6340d443075e27",
#     "b8282fe98c62451fa1dd1f166106ede6",
#     "f8a7b77ce6354acf911ea39e79266798",
#     "a27dec4f05c64499b5bebe1a38286d09",
#     "5d1d8240434d425092404067caebd57b",
#     "3a2da2437c9f49d59e43a4722090d590"
# ]

# for run_id in run_ids:
#     mlflow.delete_run(run_id)

# print("Runs deleted successfully")
# Out:
# Runs deleted successfully

# %% [markdown]
# ## Optimized Model: Model-1o-v1
#
# #### Tuning Hyperparametes using Optuna to get more optimized and effiecient Model

# %%
import optuna as optuna

# %% [markdown]
# ### Creating train,val and test set: 70,15,15

# %% [markdown]
# Note that the Model Definition will be the same throughout all models

# %%
# CELL 31 - CORRECTED DATA SPLIT

train_size_opt = int(0.70 * len(data))
val_size_opt = int(0.15 * len(data))

X_train_opt = torch.from_numpy(data[:train_size_opt, :-1, :]).type(torch.Tensor).to(device)
y_train_opt = torch.from_numpy(data[:train_size_opt, -1, :]).type(torch.Tensor).to(device)  # ✅ Fixed: train_size_opt

X_val = torch.from_numpy(data[train_size_opt:train_size_opt+val_size_opt, :-1, :]).type(torch.Tensor).to(device)  # ✅ Fixed: train_size_opt+val_size_opt
y_val = torch.from_numpy(data[train_size_opt:train_size_opt+val_size_opt, -1, :]).type(torch.Tensor).to(device)

X_test_opt = torch.from_numpy(data[train_size_opt+val_size_opt:, :-1, :]).type(torch.Tensor).to(device)
y_test_opt = torch.from_numpy(data[train_size_opt+val_size_opt:, -1, :]).type(torch.Tensor).to(device)

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
def objective(trial):
    hidden_size=trial.suggest_int(
        "hidden_size",
        32,256,
        step=32
    )
    num_layers=trial.suggest_int(
        "num_layers",
        1,3
    )
    learning_rate = trial.suggest_loguniform(
        "learning_rate", 
        1e-4, 1e-2
    )
    batch_size = trial.suggest_categorical(
        "batch_size", 
        [16, 32, 64]
    )
    epochs = trial.suggest_int(
        "epochs", 
        50, 200, 
        step=50)
    trial_model=PredictionModel(
        input_size=1,
        hidden_size=hidden_size,
        num_layers=num_layers,
        output_size=1
    ).to(device)
    optimizer=torch.optim.Adam(trial_model.parameters(),lr=learning_rate)
    criterion=nn.MSELoss()
    train_dataset=TensorDataset(X_train_opt,y_train_opt)
    train_loader=DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
    val_dataset=TensorDataset(X_val,y_val)
    val_loader=DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
    
    best_val_loss = float('inf')
    patience = 20
    patience_counter = 0
    
    for epoch in range(epochs):
        
        # Training Phase
        trial_model.train()
        train_loss = 0
        
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = trial_model(X_batch)
            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        
        # Validation Phase
        trial_model.eval()
        val_loss = 0
        
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                y_pred = trial_model(X_batch)
                loss = criterion(y_pred, y_batch)
                val_loss += loss.item()
        
        val_loss /= len(val_loader)
        
        # Early Stopping Logic
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"  Early stopping at epoch {epoch}")
                break
        
        # Report to Optuna for pruning
        trial.report(val_loss, epoch)
        
        # Optuna: Check if trial should be pruned
        if trial.should_prune():
            raise optuna.TrialPruned()
    
    return best_val_loss

# %%
def log_trial_mlflow(study,trial):
    with mlflow.start_run(run_name=f"Trial_{trial.number}"):
        # Log all hyperparameters
        mlflow.log_params(trial.params)
        
        # Log the validation loss (objective value)
        mlflow.log_metric("best_val_loss", trial.value)
        mlflow.log_metric("trial_number", trial.number)
        
        # Log trial state
        mlflow.log_param("trial_state", str(trial.state))

# %%
mlflow.set_experiment("Stock_Prediction_Optuna_Optimization")
sampler = optuna.samplers.TPESampler(seed=42)
pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)

study = optuna.create_study(
    direction='minimize',  # Minimize validation loss
    sampler=sampler,
    pruner=pruner
)

# Number of trials for hyperparameter search
n_trials = 20

print("="*70)
print("STARTING OPTUNA HYPERPARAMETER OPTIMIZATION")
print("="*70)
print(f"Number of trials: {n_trials}")
print(f"Hyperparameters to tune: hidden_size, num_layers, learning_rate, batch_size, epochs")
print("="*70 + "\n")

# Run optimization
study.optimize(
    objective,
    n_trials=n_trials,
    callbacks=[log_trial_mlflow],
    show_progress_bar=True
)

print("\n" + "="*70)
print("✓ OPTIMIZATION COMPLETE!")
print("="*70)
# Out:
# [I 2026-08-02 02:29:08,163] A new study created in memory with name: no-name-78dacfad-a696-402d-8e0b-0733c128a58f
# ======================================================================
# STARTING OPTUNA HYPERPARAMETER OPTIMIZATION
# ======================================================================
# Number of trials: 20
# Hyperparameters to tune: hidden_size, num_layers, learning_rate, batch_size, epochs
# ======================================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# C:\Users\ASTITVA MISHRA\AppData\Local\Temp\ipykernel_36240\1631187724.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform(
# [I 2026-08-02 02:29:22,746] Trial 0 finished with value: 0.002133013274763304 and parameters: {'hidden_size': 96, 'num_layers': 3, 'learning_rate': 0.0029106359131330704, 'batch_size': 16, 'epochs': 50}. Best is trial 0 with value: 0.002133013274763304.
# 🏃 View run Trial_0 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/ac58c7ed0c3849efb30402a200bb8a84
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:29:40,910] Trial 1 finished with value: 0.0020834799345013583 and parameters: {'hidden_size': 224, 'num_layers': 2, 'learning_rate': 0.0026070247583707684, 'batch_size': 32, 'epochs': 50}. Best is trial 1 with value: 0.0020834799345013583.
# 🏃 View run Trial_1 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/e00b348e08e14c52b2722c3d9975825b
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 92
# [I 2026-08-02 02:30:03,503] Trial 2 finished with value: 0.0021504615921310714 and parameters: {'hidden_size': 64, 'num_layers': 1, 'learning_rate': 0.0004059611610484307, 'batch_size': 16, 'epochs': 150}. Best is trial 1 with value: 0.0020834799345013583.
# 🏃 View run Trial_2 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/b023487e8f784afaa27ffa61589756de
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:30:24,050] Trial 3 finished with value: 0.0020776670232104757 and parameters: {'hidden_size': 64, 'num_layers': 1, 'learning_rate': 0.0005404103854647331, 'batch_size': 32, 'epochs': 150}. Best is trial 3 with value: 0.0020776670232104757.
# 🏃 View run Trial_3 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/09a4f0d9938f460e8cd73b86f8d46faa
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 86
# [I 2026-08-02 02:30:34,963] Trial 4 finished with value: 0.002080894017126411 and parameters: {'hidden_size': 160, 'num_layers': 1, 'learning_rate': 0.0016409286730647919, 'batch_size': 64, 'epochs': 200}. Best is trial 3 with value: 0.0020776670232104757.
# 🏃 View run Trial_4 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/14bbb36a0c554581973f48dace7bbe75
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:30:41,575] Trial 5 pruned.
# 🏃 View run Trial_5 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/194038d67c97401d8e86403d25b9a32c
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:30:46,663] Trial 6 pruned.
# 🏃 View run Trial_6 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/1d2abe005bae4a578895a031042776f1
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 41
# [I 2026-08-02 02:31:00,369] Trial 7 finished with value: 0.0021453523577164703 and parameters: {'hidden_size': 64, 'num_layers': 3, 'learning_rate': 0.0035503048581283078, 'batch_size': 16, 'epochs': 200}. Best is trial 3 with value: 0.0020776670232104757.
# 🏃 View run Trial_7 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/f8159e53ee254cd79e9b66591496c0af
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:31:04,225] Trial 8 pruned.
# 🏃 View run Trial_8 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/a94274febe87450f8cfa5c16374ace56
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:31:08,307] Trial 9 pruned.
# 🏃 View run Trial_9 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/205bf5093701404797f929b9db404ca8
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 51
# [I 2026-08-02 02:31:27,019] Trial 10 finished with value: 0.0020937864060720634 and parameters: {'hidden_size': 160, 'num_layers': 2, 'learning_rate': 0.008691089486124966, 'batch_size': 64, 'epochs': 100}. Best is trial 3 with value: 0.0020776670232104757.
# 🏃 View run Trial_10 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/9f7fe445826d402d8453166739c6ff2a
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:31:42,094] Trial 11 pruned.
# 🏃 View run Trial_11 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/a77a80446131402a80825c734d4b780e
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:31:58,634] Trial 12 pruned.
# 🏃 View run Trial_12 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/eb3a20b20a9a460b8342f93290e21af7
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:32:14,896] Trial 13 pruned.
# 🏃 View run Trial_13 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/a80b040ff9d74e19b48179dd8d31d562
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:32:30,596] Trial 14 pruned.
# 🏃 View run Trial_14 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/cf10f6c51bf24633ab8d3bca0f1da859
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:32:39,093] Trial 15 pruned.
# 🏃 View run Trial_15 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/46350e04e2934b7b94ec9039b7d7f23b
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:32:50,685] Trial 16 pruned.
# 🏃 View run Trial_16 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/5b35a62304154c64b74d3c68dea576d1
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 55
# [I 2026-08-02 02:33:08,248] Trial 17 finished with value: 0.002069439538495822 and parameters: {'hidden_size': 96, 'num_layers': 1, 'learning_rate': 0.008062043915943224, 'batch_size': 64, 'epochs': 150}. Best is trial 17 with value: 0.002069439538495822.
# 🏃 View run Trial_17 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/8f52e2aa5831467f93347658677bfcf4
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#   Early stopping at epoch 34
# [I 2026-08-02 02:33:19,186] Trial 18 finished with value: 0.002149755461788219 and parameters: {'hidden_size': 64, 'num_layers': 2, 'learning_rate': 0.008380682553369266, 'batch_size': 32, 'epochs': 100}. Best is trial 17 with value: 0.002069439538495822.
# 🏃 View run Trial_18 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/ccb0aa098a324a89bf221130d8909fbd
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
# [I 2026-08-02 02:33:25,347] Trial 19 pruned.
# 🏃 View run Trial_19 at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1/runs/63ede1cab2c24abf887698100606e69f
# 🧪 View experiment at: https://dagshub.com/astitvamishra0393/Stock_price_LSTM.mlflow/#/experiments/1
#
# ======================================================================
# ✓ OPTIMIZATION COMPLETE!
# ======================================================================
